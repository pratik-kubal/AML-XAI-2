# %%
import numpy as np
import pandas as pd
import cv2
from matplotlib import pyplot as plt
from keras.regularizers import l1_l2
from keras.models import Model, clone_model
from keras.layers import Input, Flatten, Dense, Dropout, Lambda, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Concatenate, Activation, Subtract, merge, Reshape, UpSampling2D
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from keras import backend as K
from keras import optimizers
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm_notebook
from os import listdir
from os.path import isfile, join
from keras.utils import to_categorical
# %matplotlib inline

# %%
stickyPath = "../dataset/seen-dataset/TrainingSet/"
seenData = [f for f in listdir(stickyPath) if isfile(join(stickyPath, f))]
testData = [f for f in listdir("../dataset/seen-dataset/ValidationSet/") if isfile(join("../dataset/seen-dataset/ValidationSet/", f))]

# %%
trainData = seenData[0:int(len(seenData)*0.9)]
valData = seenData[int(len(seenData)*0.9):]

# %%
feature_data = pd.read_csv("../dataset/15features.csv")

# %%
feature_data.head()
# Out:
#         imagename  pen_pressure  letter_spacing  size  dimension  \
# 0  0968c_num1.png             2               2     2          1
# 1  0809c_num2.png             2               2     2          2
# 2  0237b_num6.png             2               2     2          2
# 3  0069b_num2.png             2               2     2          1
# 4  0966c_num4.png             2               2     2          2
#
#    is_lowercase  is_continuous  slantness  tilt  entry_stroke_a  staff_of_a  \
# 0             2              2          3     2               1           2
# 1             2              2          3     1               1           2
# 2             2              2          2     2               1           2
# 3             2              2          1     1               1           1
# 4             2              2          2     1               1           2
#
#    formation_n  staff_of_d  exit_stroke_d  word_formation  constancy
# 0            2           3              2               2          1
# 1            2           3              1               2          2
# 2            2           2              2               2          2
# 3            1           1              1               1          1
# 4            2           2              2               2          2

# %%
cat_dict = {}
for idx,columns in enumerate(feature_data.columns):
    if columns != "imagename":
        cat_dict[idx]=len(np.unique(feature_data[columns]))
cat_dict
# Out:
# {1: 2,
#  2: 3,
#  3: 3,
#  4: 3,
#  5: 2,
#  6: 2,
#  7: 4,
#  8: 2,
#  9: 2,
#  10: 4,
#  11: 2,
#  12: 3,
#  13: 4,
#  14: 2,
#  15: 2}

# %%
for idx,columns in enumerate(feature_data.columns):
    if columns != "imagename":
        feature_data[str(columns)] = feature_data[str(columns)] - 1
        feature_data[str(columns)] = list(to_categorical(feature_data[str(columns)],num_classes=cat_dict[idx]))

# %%
train_features = feature_data[feature_data["imagename"].isin(trainData)]
val_features = feature_data[feature_data["imagename"].isin(valData)]
test_features = feature_data[feature_data["imagename"].isin(testData)]

# %%
def datagen(batchSize,train_features,stickyPath):
    idx = 0
    hshift = (-64,64)
    vshift = (-64,64)
    while(True):
        subset = train_features.sample(n=batchSize).reset_index(drop=True)
        data = list(subset.imagename)
        returnInput=[]
        returnOutput=[]
        f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15 = [],[],[],[],[],[],[],[],[],[],[],[],[],[],[]
        for image in data:
            skeleton = []
            left = cv2.imread(str(stickyPath+image),cv2.IMREAD_GRAYSCALE)
            #right = data.iloc[row,1]
            #right = cv2.imread(str("../dataset/seen-dataset/TrainingSet/"+right),cv2.IMREAD_GRAYSCALE)
            
            # Floating Point
            leftImage = left.astype('float32')
            leftImage /= 255
            leftImage = 1 - leftImage
            #rightImage = right.astype('float32')
            #rightImage /= 255
            
            temp=[leftImage]

            skeleton.append(temp)
            
            features = train_features[train_features.imagename == image].iloc[:,1:].values
            f1.append(np.array(features[0][0],dtype='int32').tolist())
            f2.append(np.array(features[0][1],dtype='int32').tolist())
            f3.append(np.array(features[0][2],dtype='int32').tolist())
            f4.append(np.array(features[0][3],dtype='int32').tolist())
            f5.append(np.array(features[0][4],dtype='int32').tolist())
            f6.append(np.array(features[0][5],dtype='int32').tolist())
            f7.append(np.array(features[0][6],dtype='int32').tolist())
            f8.append(np.array(features[0][7],dtype='int32').tolist())
            f9.append(np.array(features[0][8],dtype='int32').tolist())
            f10.append(np.array(features[0][9],dtype='int32').tolist())
            f11.append(np.array(features[0][10],dtype='int32').tolist())
            f12.append(np.array(features[0][11],dtype='int32').tolist())
            f13.append(np.array(features[0][12],dtype='int32').tolist())
            f14.append(np.array(features[0][13],dtype='int32').tolist())
            f15.append(np.array(features[0][14],dtype='int32').tolist())
            
            # Shifting
            randH = np.random.randint(hshift[0],hshift[1])
            randV = np.random.randint(vshift[0],vshift[1])
            
            leftImageShiftedH=np.roll(axis=0,a=leftImage,shift=randH)
            #rightImageShiftedH=np.roll(axis=0,a=rightImage,shift=randH)
            
            leftImageShiftedV=np.roll(axis=0,a=leftImage,shift=randV)
            #rightImageShiftedV=np.roll(axis=0,a=rightImage,shift=randV)
            
            temp = [leftImageShiftedV]
            skeleton.append(temp)
            f1.append(np.array(features[0][0],dtype='int32').tolist())
            f2.append(np.array(features[0][1],dtype='int32').tolist())
            f3.append(np.array(features[0][2],dtype='int32').tolist())
            f4.append(np.array(features[0][3],dtype='int32').tolist())
            f5.append(np.array(features[0][4],dtype='int32').tolist())
            f6.append(np.array(features[0][5],dtype='int32').tolist())
            f7.append(np.array(features[0][6],dtype='int32').tolist())
            f8.append(np.array(features[0][7],dtype='int32').tolist())
            f9.append(np.array(features[0][8],dtype='int32').tolist())
            f10.append(np.array(features[0][9],dtype='int32').tolist())
            f11.append(np.array(features[0][10],dtype='int32').tolist())
            f12.append(np.array(features[0][11],dtype='int32').tolist())
            f13.append(np.array(features[0][12],dtype='int32').tolist())
            f14.append(np.array(features[0][13],dtype='int32').tolist())
            f15.append(np.array(features[0][14],dtype='int32').tolist())
            
            
            temp = [leftImageShiftedH]
            skeleton.append(temp)
            
            f1.append(np.array(features[0][0],dtype='int32').tolist())
            f2.append(np.array(features[0][1],dtype='int32').tolist())
            f3.append(np.array(features[0][2],dtype='int32').tolist())
            f4.append(np.array(features[0][3],dtype='int32').tolist())
            f5.append(np.array(features[0][4],dtype='int32').tolist())
            f6.append(np.array(features[0][5],dtype='int32').tolist())
            f7.append(np.array(features[0][6],dtype='int32').tolist())
            f8.append(np.array(features[0][7],dtype='int32').tolist())
            f9.append(np.array(features[0][8],dtype='int32').tolist())
            f10.append(np.array(features[0][9],dtype='int32').tolist())
            f11.append(np.array(features[0][10],dtype='int32').tolist())
            f12.append(np.array(features[0][11],dtype='int32').tolist())
            f13.append(np.array(features[0][12],dtype='int32').tolist())
            f14.append(np.array(features[0][13],dtype='int32').tolist())
            f15.append(np.array(features[0][14],dtype='int32').tolist())
            
            returnInput.append(skeleton)
            

            
        returnInput = np.array(returnInput)
        returnInput = returnInput.reshape(batchSize*3,64,64)
        
        blank =[]
        
        blank.append(returnInput)
        
        returnInput = np.array(blank)
        
        returnInput = np.moveaxis(returnInput,0,3)
        
        outList = [f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15]

        for idx,item in enumerate(outList):
            outList[idx] = np.array(item)
        
        yield returnInput,outList

# %%
trainGenObj = datagen(10,train_features,stickyPath)

# %%
image,feat= next(trainGenObj)

# %%
image.shape
# Out:
# (30, 64, 64, 1)

# %%
input_img = Input(shape=(64, 64, 1))  # adapt this if using `channels_first` image data format
x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)
encoded = Flatten()(x)
encoded = Dense(8*8*8, activation='relu', name='latent')(encoded)
# model = Model(input_img,encoded)
# print(model.summary())
# at this point the representation is (4, 4, 8) i.e. 128-dimensional
r = Reshape(target_shape=(8,8,8))(encoded)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(r)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
#x = BatchNormalization()(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='output')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='RMSprop', loss='binary_crossentropy')

#display(SVG(model_to_dot(autoencoder, show_layer_names=True, show_shapes=True, rankdir='TB').create(prog='dot', format='svg')))
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/aml/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
autoencoder.load_weights("weights/simple_ae_maxpool_Seen_weights_v1.h5")

# %%
encoder = Model(inputs=autoencoder.inputs,outputs=autoencoder.get_layer('latent').output)

# %%
#display(SVG(model_to_dot(encoder, show_layer_names=True, show_shapes=True, rankdir='TB').create(prog='dot', format='svg')))

# %% [markdown]
# ### Frezzing weights

# %%
for layer in encoder.layers:
    layer.trainable = False

# %%
_input = encoder.output
# Feature1
layerf1 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf1 = BatchNormalization()(layerf1)

# Feature2
layerf2 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf2 = BatchNormalization()(layerf2)
layerf2 = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf2)
layerf2 = BatchNormalization()(layerf2)

# Feature3
layerf3 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf3 = BatchNormalization()(layerf3)

# Feature4
layerf4 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf4 = BatchNormalization()(layerf4)
layerf4 = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf4)
layerf4 = BatchNormalization()(layerf4)

# Feature5
layerf5_c = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf5_c = BatchNormalization()(layerf5_c)
layerf5_c = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf5_c)
layerf5 = BatchNormalization()(layerf5_c)

# Feature6
layerf6 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf6 = BatchNormalization()(layerf6)
layerf6 = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf6)
layerf6 = Concatenate()([layerf6,layerf5_c])
layerf6 = BatchNormalization()(layerf6)

# Feature7
layerf7_c = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf7_c = BatchNormalization()(layerf7_c)
layerf7_c = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf7_c)
layerf7 = BatchNormalization()(layerf7_c)

# Feature8
layerf8 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf8 = BatchNormalization()(layerf8)
layerf8 = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf8)
layerf8 = Concatenate()([layerf8,layerf7_c])
layerf8 = BatchNormalization()(layerf8)

# Feature9
layerf9_c = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf9 = BatchNormalization()(layerf9_c)

# Feature10
layerf10_c = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf10_c = BatchNormalization()(layerf10_c)
layerf10_c = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf10_c)
layerf10 = BatchNormalization()(layerf10_c)

# Feature11
layerf11 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf11 = BatchNormalization()(layerf11)
layerf11 = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf11)
layerf11 = BatchNormalization()(layerf11)

# Feature12
layerf12 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf12 = BatchNormalization()(layerf12)
layerf12 = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf12)
layerf12 = Concatenate()([layerf12,layerf10_c])
layerf12 = BatchNormalization()(layerf12)

# Feature13
layerf13 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf13 = Concatenate()([layerf13,layerf9_c])
layerf13 = BatchNormalization()(layerf13)

# Feature14
layerf14 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf14 = BatchNormalization()(layerf14)

# Feature15
layerf15 = Dense(128,activation='relu',kernel_initializer="glorot_normal")(_input)
layerf15 = BatchNormalization()(layerf15)
layerf15 = Dense(64,activation='relu',kernel_initializer="glorot_normal")(layerf15)
layerf15 = BatchNormalization()(layerf15)


layerOut1 = Dense(2,activation='softmax',name="pen_pressure",kernel_initializer="glorot_normal")(layerf1)
layerOut2 = Dense(3,activation='softmax',name="letter_spacing",kernel_initializer="glorot_normal")(layerf2)
layerOut3 = Dense(3,activation='softmax',name="size",kernel_initializer="glorot_normal")(layerf3)
layerOut4 = Dense(3,activation='softmax',name="dimension",kernel_initializer="glorot_normal")(layerf4)
layerOut5 = Dense(2,activation='softmax',name="is_lowercase",kernel_initializer="glorot_normal")(layerf5)
layerOut6 = Dense(2,activation='softmax',name="is_continuous",kernel_initializer="glorot_normal")(layerf6)
layerOut7 = Dense(4,activation='softmax',name="slantness",kernel_initializer="glorot_normal")(layerf7)
layerOut8 = Dense(2,activation='softmax',name="tilt",kernel_initializer="glorot_normal")(layerf8)
layerOut9 = Dense(2,activation='softmax',name="entry_stroke_a",kernel_initializer="glorot_normal")(layerf9)
layerOut10 = Dense(4,activation='softmax',name="staff_of_a",kernel_initializer="glorot_normal")(layerf10)
layerOut11 = Dense(2,activation='softmax',name="formation_n",kernel_initializer="glorot_normal")(layerf11)
layerOut12 = Dense(3,activation='softmax',name="staff_of_d",kernel_initializer="glorot_normal")(layerf12)
layerOut13 = Dense(4,activation='softmax',name="exit_stroke_d",kernel_initializer="glorot_normal")(layerf13)
layerOut14 = Dense(2,activation='softmax',name="word_formation",kernel_initializer="glorot_normal")(layerf14)
layerOut15 = Dense(2,activation='softmax',name="constancy",kernel_initializer="glorot_normal")(layerf15)

# %%
xai_NN = Model(encoder.input,[layerOut1,layerOut2,layerOut3,layerOut4,layerOut5,
                                 layerOut6,layerOut7,layerOut8,layerOut9,layerOut10,
                                layerOut11,layerOut12,layerOut13,layerOut14,layerOut15])

# %%
display(SVG(model_to_dot(xai_NN, show_layer_names=True, show_shapes=True, rankdir='TB').create(prog='dot', format='svg')))

# %%
lossesDict = {}
for idx,column in enumerate(train_features.columns):
    if idx  != 0:
        lossesDict[columns] = "categorical_crossentropy"

adam = optimizers.Adam(lr=0.1, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
xai_NN.compile(optimizer=adam, loss='categorical_crossentropy',metrics=['categorical_accuracy'])

# %%
batchSize=25
trainGenObj = datagen(batchSize,train_features,stickyPath)
valGenObj = datagen(len(val_features),val_features,stickyPath)
testGenObj = datagen(len(test_features),test_features,"../dataset/seen-dataset/ValidationSet/")

# %%
LOG_DIR = './log/xai/seen'
#runIter = 0

# %%
mc = ModelCheckpoint(filepath='weights/xai_seen_weights_v1.h5', 
                     monitor='val_loss',period=1,save_best_only=True,
                     save_weights_only=True,mode='auto',verbose=1)
es = EarlyStopping(patience=700, monitor='val_loss', min_delta=0.0005, mode='auto')
tbCallBack = TensorBoard(log_dir=str(LOG_DIR+"/run"+str(runIter)), histogram_freq=0,
                         write_graph=True,
                         write_grads=True,
                         batch_size=batchSize,
                         write_images=True)
runIter+=1

# %%
xai_NN.fit_generator(
    trainGenObj,
    epochs=10,
    verbose=1,
    validation_data=valGenObj,
    validation_steps=1,
    steps_per_epoch=((len(trainData)//batchSize)*3),
    callbacks=[es,tbCallBack]
)
# Out:
# Epoch 1/10
# 1386/1386 [==============================] - 139s 100ms/step - loss: 10.7299 - pen_pressure_loss: 0.4804 - letter_spacing_loss: 1.0061 - size_loss: 0.7789 - dimension_loss: 0.8067 - is_lowercase_loss: 0.0929 - is_continuous_loss: 0.5988 - slantness_loss: 1.0343 - tilt_loss: 0.5219 - entry_stroke_a_loss: 0.1908 - staff_of_a_loss: 1.1439 - formation_n_loss: 0.5341 - staff_of_d_loss: 0.9283 - exit_stroke_d_loss: 1.2437 - word_formation_loss: 0.6873 - constancy_loss: 0.6818 - pen_pressure_categorical_accuracy: 0.7831 - letter_spacing_categorical_accuracy: 0.5180 - size_categorical_accuracy: 0.6405 - dimension_categorical_accuracy: 0.6174 - is_lowercase_categorical_accuracy: 0.9821 - is_continuous_categorical_accuracy: 0.7069 - slantness_categorical_accuracy: 0.5531 - tilt_categorical_accuracy: 0.8024 - entry_stroke_a_categorical_accuracy: 0.9408 - staff_of_a_categorical_accuracy: 0.5746 - formation_n_categorical_accuracy: 0.7576 - staff_of_d_categorical_accuracy: 0.5505 - exit_stroke_d_categorical_accuracy: 0.4536 - word_formation_categorical_accuracy: 0.5956 - constancy_categorical_accuracy: 0.5958 - val_loss: 25.3596 - val_pen_pressure_loss: 1.5483 - val_letter_spacing_loss: 1.0446 - val_size_loss: 0.9764 - val_dimension_loss: 10.3189 - val_is_lowercase_loss: 0.1384 - val_is_continuous_loss: 0.5934 - val_slantness_loss: 1.2229 - val_tilt_loss: 2.8811 - val_entry_stroke_a_loss: 0.1851 - val_staff_of_a_loss: 1.2201 - val_formation_n_loss: 0.9439 - val_staff_of_d_loss: 1.1056 - val_exit_stroke_d_loss: 1.1666 - val_word_formation_loss: 0.6646 - val_constancy_loss: 1.3498 - val_pen_pressure_categorical_accuracy: 0.4975 - val_letter_spacing_categorical_accuracy: 0.4938 - val_size_categorical_accuracy: 0.6150 - val_dimension_categorical_accuracy: 0.3288 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.7342 - val_slantness_categorical_accuracy: 0.5473 - val_tilt_categorical_accuracy: 0.7813 - val_entry_stroke_a_categorical_accuracy: 0.9391 - val_staff_of_a_categorical_accuracy: 0.4448 - val_formation_n_categorical_accuracy: 0.4398 - val_staff_of_d_categorical_accuracy: 0.4866 - val_exit_stroke_d_categorical_accuracy: 0.4845 - val_word_formation_categorical_accuracy: 0.6399 - val_constancy_categorical_accuracy: 0.4186
# Epoch 2/10
# 1386/1386 [==============================] - 117s 84ms/step - loss: 10.3956 - pen_pressure_loss: 0.4467 - letter_spacing_loss: 0.9820 - size_loss: 0.7711 - dimension_loss: 0.7762 - is_lowercase_loss: 0.0709 - is_continuous_loss: 0.5618 - slantness_loss: 0.9710 - tilt_loss: 0.5113 - entry_stroke_a_loss: 0.1744 - staff_of_a_loss: 1.1314 - formation_n_loss: 0.5223 - staff_of_d_loss: 0.9033 - exit_stroke_d_loss: 1.2229 - word_formation_loss: 0.6849 - constancy_loss: 0.6656 - pen_pressure_categorical_accuracy: 0.7994 - letter_spacing_categorical_accuracy: 0.5315 - size_categorical_accuracy: 0.6439 - dimension_categorical_accuracy: 0.6330 - is_lowercase_categorical_accuracy: 0.9857 - is_continuous_categorical_accuracy: 0.7294 - slantness_categorical_accuracy: 0.5843 - tilt_categorical_accuracy: 0.8038 - entry_stroke_a_categorical_accuracy: 0.9445 - staff_of_a_categorical_accuracy: 0.5736 - formation_n_categorical_accuracy: 0.7589 - staff_of_d_categorical_accuracy: 0.5759 - exit_stroke_d_categorical_accuracy: 0.4554 - word_formation_categorical_accuracy: 0.5999 - constancy_categorical_accuracy: 0.6094 - val_loss: 16.2215 - val_pen_pressure_loss: 0.3527 - val_letter_spacing_loss: 0.9953 - val_size_loss: 0.7470 - val_dimension_loss: 0.8480 - val_is_lowercase_loss: 0.1734 - val_is_continuous_loss: 0.7188 - val_slantness_loss: 2.2803 - val_tilt_loss: 0.9543 - val_entry_stroke_a_loss: 1.8113 - val_staff_of_a_loss: 1.2397 - val_formation_n_loss: 0.7748 - val_staff_of_d_loss: 2.0678 - val_exit_stroke_d_loss: 1.3333 - val_word_formation_loss: 0.7740 - val_constancy_loss: 1.1509 - val_pen_pressure_categorical_accuracy: 0.8366 - val_letter_spacing_categorical_accuracy: 0.5197 - val_size_categorical_accuracy: 0.6330 - val_dimension_categorical_accuracy: 0.5748 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.6966 - val_slantness_categorical_accuracy: 0.1697 - val_tilt_categorical_accuracy: 0.7895 - val_entry_stroke_a_categorical_accuracy: 0.3524 - val_staff_of_a_categorical_accuracy: 0.4406 - val_formation_n_categorical_accuracy: 0.7750 - val_staff_of_d_categorical_accuracy: 0.3961 - val_exit_stroke_d_categorical_accuracy: 0.4072 - val_word_formation_categorical_accuracy: 0.5766 - val_constancy_categorical_accuracy: 0.4342
# Epoch 3/10
# 1386/1386 [==============================] - 118s 85ms/step - loss: 10.4260 - pen_pressure_loss: 0.4420 - letter_spacing_loss: 0.9822 - size_loss: 0.7438 - dimension_loss: 0.7787 - is_lowercase_loss: 0.2378 - is_continuous_loss: 0.5664 - slantness_loss: 0.9380 - tilt_loss: 0.5296 - entry_stroke_a_loss: 0.1605 - staff_of_a_loss: 1.1155 - formation_n_loss: 0.5121 - staff_of_d_loss: 0.8816 - exit_stroke_d_loss: 1.1990 - word_formation_loss: 0.6730 - constancy_loss: 0.6658 - pen_pressure_categorical_accuracy: 0.8000 - letter_spacing_categorical_accuracy: 0.5272 - size_categorical_accuracy: 0.6549 - dimension_categorical_accuracy: 0.6340 - is_lowercase_categorical_accuracy: 0.9843 - is_continuous_categorical_accuracy: 0.7306 - slantness_categorical_accuracy: 0.5914 - tilt_categorical_accuracy: 0.7951 - entry_stroke_a_categorical_accuracy: 0.9476 - staff_of_a_categorical_accuracy: 0.5738 - formation_n_categorical_accuracy: 0.7618 - staff_of_d_categorical_accuracy: 0.5928 - exit_stroke_d_categorical_accuracy: 0.4639 - word_formation_categorical_accuracy: 0.6127 - constancy_categorical_accuracy: 0.6140 - val_loss: 13.3244 - val_pen_pressure_loss: 0.3444 - val_letter_spacing_loss: 1.2036 - val_size_loss: 1.1127 - val_dimension_loss: 0.8959 - val_is_lowercase_loss: 0.3201 - val_is_continuous_loss: 0.6147 - val_slantness_loss: 1.6441 - val_tilt_loss: 0.5778 - val_entry_stroke_a_loss: 0.2980 - val_staff_of_a_loss: 1.2344 - val_formation_n_loss: 0.8185 - val_staff_of_d_loss: 1.2730 - val_exit_stroke_d_loss: 1.5958 - val_word_formation_loss: 0.6692 - val_constancy_loss: 0.7224 - val_pen_pressure_categorical_accuracy: 0.8525 - val_letter_spacing_categorical_accuracy: 0.4053 - val_size_categorical_accuracy: 0.5690 - val_dimension_categorical_accuracy: 0.5870 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.7122 - val_slantness_categorical_accuracy: 0.5279 - val_tilt_categorical_accuracy: 0.7895 - val_entry_stroke_a_categorical_accuracy: 0.9378 - val_staff_of_a_categorical_accuracy: 0.5811 - val_formation_n_categorical_accuracy: 0.7744 - val_staff_of_d_categorical_accuracy: 0.5250 - val_exit_stroke_d_categorical_accuracy: 0.3294 - val_word_formation_categorical_accuracy: 0.6299 - val_constancy_categorical_accuracy: 0.5925
# Epoch 4/10
# 1386/1386 [==============================] - 119s 86ms/step - loss: 10.3539 - pen_pressure_loss: 0.4358 - letter_spacing_loss: 0.9906 - size_loss: 0.7648 - dimension_loss: 0.7806 - is_lowercase_loss: 0.2303 - is_continuous_loss: 0.5466 - slantness_loss: 0.9399 - tilt_loss: 0.5090 - entry_stroke_a_loss: 0.1528 - staff_of_a_loss: 1.1162 - formation_n_loss: 0.5072 - staff_of_d_loss: 0.8714 - exit_stroke_d_loss: 1.1727 - word_formation_loss: 0.6772 - constancy_loss: 0.6590 - pen_pressure_categorical_accuracy: 0.8051 - letter_spacing_categorical_accuracy: 0.5188 - size_categorical_accuracy: 0.6446 - dimension_categorical_accuracy: 0.6319 - is_lowercase_categorical_accuracy: 0.9857 - is_continuous_categorical_accuracy: 0.7366 - slantness_categorical_accuracy: 0.5906 - tilt_categorical_accuracy: 0.8056 - entry_stroke_a_categorical_accuracy: 0.9509 - staff_of_a_categorical_accuracy: 0.5739 - formation_n_categorical_accuracy: 0.7641 - staff_of_d_categorical_accuracy: 0.6026 - exit_stroke_d_categorical_accuracy: 0.4817 - word_formation_categorical_accuracy: 0.6079 - constancy_categorical_accuracy: 0.6186 - val_loss: 12.2928 - val_pen_pressure_loss: 0.4567 - val_letter_spacing_loss: 1.1200 - val_size_loss: 0.7634 - val_dimension_loss: 1.2354 - val_is_lowercase_loss: 0.3201 - val_is_continuous_loss: 0.6839 - val_slantness_loss: 1.3733 - val_tilt_loss: 0.5217 - val_entry_stroke_a_loss: 0.3748 - val_staff_of_a_loss: 1.1197 - val_formation_n_loss: 0.5464 - val_staff_of_d_loss: 0.9750 - val_exit_stroke_d_loss: 1.3405 - val_word_formation_loss: 0.7946 - val_constancy_loss: 0.6673 - val_pen_pressure_categorical_accuracy: 0.7861 - val_letter_spacing_categorical_accuracy: 0.5168 - val_size_categorical_accuracy: 0.6293 - val_dimension_categorical_accuracy: 0.5669 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.6415 - val_slantness_categorical_accuracy: 0.2806 - val_tilt_categorical_accuracy: 0.7895 - val_entry_stroke_a_categorical_accuracy: 0.9367 - val_staff_of_a_categorical_accuracy: 0.5917 - val_formation_n_categorical_accuracy: 0.7752 - val_staff_of_d_categorical_accuracy: 0.5507 - val_exit_stroke_d_categorical_accuracy: 0.4583 - val_word_formation_categorical_accuracy: 0.5007 - val_constancy_categorical_accuracy: 0.6235
# Epoch 5/10
# 1386/1386 [==============================] - 120s 87ms/step - loss: 10.3914 - pen_pressure_loss: 0.4418 - letter_spacing_loss: 0.9860 - size_loss: 0.7555 - dimension_loss: 0.7785 - is_lowercase_loss: 0.2289 - is_continuous_loss: 0.5616 - slantness_loss: 0.9127 - tilt_loss: 0.5199 - entry_stroke_a_loss: 0.1762 - staff_of_a_loss: 1.1095 - formation_n_loss: 0.5188 - staff_of_d_loss: 0.8594 - exit_stroke_d_loss: 1.1896 - word_formation_loss: 0.6831 - constancy_loss: 0.6700 - pen_pressure_categorical_accuracy: 0.8038 - letter_spacing_categorical_accuracy: 0.5173 - size_categorical_accuracy: 0.6512 - dimension_categorical_accuracy: 0.6341 - is_lowercase_categorical_accuracy: 0.9858 - is_continuous_categorical_accuracy: 0.7341 - slantness_categorical_accuracy: 0.6010 - tilt_categorical_accuracy: 0.7995 - entry_stroke_a_categorical_accuracy: 0.9472 - staff_of_a_categorical_accuracy: 0.5757 - formation_n_categorical_accuracy: 0.7584 - staff_of_d_categorical_accuracy: 0.6117 - exit_stroke_d_categorical_accuracy: 0.4772 - word_formation_categorical_accuracy: 0.6051 - constancy_categorical_accuracy: 0.6070 - val_loss: 11.6990 - val_pen_pressure_loss: 0.3904 - val_letter_spacing_loss: 0.9448 - val_size_loss: 0.8447 - val_dimension_loss: 0.8648 - val_is_lowercase_loss: 0.3201 - val_is_continuous_loss: 0.7581 - val_slantness_loss: 1.1911 - val_tilt_loss: 0.7188 - val_entry_stroke_a_loss: 0.1887 - val_staff_of_a_loss: 1.1763 - val_formation_n_loss: 0.5144 - val_staff_of_d_loss: 0.8122 - val_exit_stroke_d_loss: 1.6016 - val_word_formation_loss: 0.7006 - val_constancy_loss: 0.6725 - val_pen_pressure_categorical_accuracy: 0.8242 - val_letter_spacing_categorical_accuracy: 0.5552 - val_size_categorical_accuracy: 0.6145 - val_dimension_categorical_accuracy: 0.5692 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.7064 - val_slantness_categorical_accuracy: 0.5886 - val_tilt_categorical_accuracy: 0.7895 - val_entry_stroke_a_categorical_accuracy: 0.9399 - val_staff_of_a_categorical_accuracy: 0.5841 - val_formation_n_categorical_accuracy: 0.7826 - val_staff_of_d_categorical_accuracy: 0.6452 - val_exit_stroke_d_categorical_accuracy: 0.4339 - val_word_formation_categorical_accuracy: 0.5682 - val_constancy_categorical_accuracy: 0.5830
# Epoch 6/10
# 1386/1386 [==============================] - 119s 86ms/step - loss: 10.3289 - pen_pressure_loss: 0.4478 - letter_spacing_loss: 0.9838 - size_loss: 0.7500 - dimension_loss: 0.7800 - is_lowercase_loss: 0.2484 - is_continuous_loss: 0.5706 - slantness_loss: 0.9223 - tilt_loss: 0.5045 - entry_stroke_a_loss: 0.1500 - staff_of_a_loss: 1.1132 - formation_n_loss: 0.5161 - staff_of_d_loss: 0.8517 - exit_stroke_d_loss: 1.1497 - word_formation_loss: 0.6696 - constancy_loss: 0.6712 - pen_pressure_categorical_accuracy: 0.8040 - letter_spacing_categorical_accuracy: 0.5225 - size_categorical_accuracy: 0.6519 - dimension_categorical_accuracy: 0.6314 - is_lowercase_categorical_accuracy: 0.9846 - is_continuous_categorical_accuracy: 0.7348 - slantness_categorical_accuracy: 0.5995 - tilt_categorical_accuracy: 0.8049 - entry_stroke_a_categorical_accuracy: 0.9517 - staff_of_a_categorical_accuracy: 0.5730 - formation_n_categorical_accuracy: 0.7568 - staff_of_d_categorical_accuracy: 0.6156 - exit_stroke_d_categorical_accuracy: 0.4929 - word_formation_categorical_accuracy: 0.6144 - constancy_categorical_accuracy: 0.6063 - val_loss: 11.2762 - val_pen_pressure_loss: 0.4921 - val_letter_spacing_loss: 0.9646 - val_size_loss: 0.7149 - val_dimension_loss: 0.7915 - val_is_lowercase_loss: 0.3201 - val_is_continuous_loss: 0.8910 - val_slantness_loss: 0.9990 - val_tilt_loss: 0.5498 - val_entry_stroke_a_loss: 0.1677 - val_staff_of_a_loss: 1.0818 - val_formation_n_loss: 0.6095 - val_staff_of_d_loss: 1.0322 - val_exit_stroke_d_loss: 1.2648 - val_word_formation_loss: 0.6452 - val_constancy_loss: 0.7521 - val_pen_pressure_categorical_accuracy: 0.7832 - val_letter_spacing_categorical_accuracy: 0.5369 - val_size_categorical_accuracy: 0.6770 - val_dimension_categorical_accuracy: 0.6558 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.6939 - val_slantness_categorical_accuracy: 0.5769 - val_tilt_categorical_accuracy: 0.7895 - val_entry_stroke_a_categorical_accuracy: 0.9460 - val_staff_of_a_categorical_accuracy: 0.5822 - val_formation_n_categorical_accuracy: 0.6645 - val_staff_of_d_categorical_accuracy: 0.5653 - val_exit_stroke_d_categorical_accuracy: 0.4604 - val_word_formation_categorical_accuracy: 0.6336 - val_constancy_categorical_accuracy: 0.5579
# Epoch 7/10
# 1386/1386 [==============================] - 119s 86ms/step - loss: 10.3325 - pen_pressure_loss: 0.4471 - letter_spacing_loss: 0.9814 - size_loss: 0.7459 - dimension_loss: 0.7720 - is_lowercase_loss: 0.2377 - is_continuous_loss: 0.5610 - slantness_loss: 0.9178 - tilt_loss: 0.5071 - entry_stroke_a_loss: 0.1774 - staff_of_a_loss: 1.1182 - formation_n_loss: 0.5086 - staff_of_d_loss: 0.8641 - exit_stroke_d_loss: 1.1511 - word_formation_loss: 0.6770 - constancy_loss: 0.6662 - pen_pressure_categorical_accuracy: 0.8038 - letter_spacing_categorical_accuracy: 0.5247 - size_categorical_accuracy: 0.6593 - dimension_categorical_accuracy: 0.6362 - is_lowercase_categorical_accuracy: 0.9853 - is_continuous_categorical_accuracy: 0.7332 - slantness_categorical_accuracy: 0.5972 - tilt_categorical_accuracy: 0.8080 - entry_stroke_a_categorical_accuracy: 0.9464 - staff_of_a_categorical_accuracy: 0.5728 - formation_n_categorical_accuracy: 0.7608 - staff_of_d_categorical_accuracy: 0.6102 - exit_stroke_d_categorical_accuracy: 0.4954 - word_formation_categorical_accuracy: 0.6104 - constancy_categorical_accuracy: 0.6140 - val_loss: 12.6583 - val_pen_pressure_loss: 0.5400 - val_letter_spacing_loss: 0.9834 - val_size_loss: 0.9533 - val_dimension_loss: 0.7799 - val_is_lowercase_loss: 0.3201 - val_is_continuous_loss: 1.7194 - val_slantness_loss: 0.8769 - val_tilt_loss: 0.5098 - val_entry_stroke_a_loss: 0.3479 - val_staff_of_a_loss: 1.0684 - val_formation_n_loss: 0.5046 - val_staff_of_d_loss: 1.0267 - val_exit_stroke_d_loss: 1.3307 - val_word_formation_loss: 0.6599 - val_constancy_loss: 1.0374 - val_pen_pressure_categorical_accuracy: 0.7434 - val_letter_spacing_categorical_accuracy: 0.5168 - val_size_categorical_accuracy: 0.5613 - val_dimension_categorical_accuracy: 0.6473 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.6876 - val_slantness_categorical_accuracy: 0.6256 - val_tilt_categorical_accuracy: 0.7895 - val_entry_stroke_a_categorical_accuracy: 0.8552 - val_staff_of_a_categorical_accuracy: 0.5917 - val_formation_n_categorical_accuracy: 0.7810 - val_staff_of_d_categorical_accuracy: 0.5703 - val_exit_stroke_d_categorical_accuracy: 0.4702 - val_word_formation_categorical_accuracy: 0.6320 - val_constancy_categorical_accuracy: 0.4498
# Epoch 8/10
# 1386/1386 [==============================] - 119s 86ms/step - loss: 10.2811 - pen_pressure_loss: 0.4392 - letter_spacing_loss: 0.9829 - size_loss: 0.7454 - dimension_loss: 0.7702 - is_lowercase_loss: 0.2451 - is_continuous_loss: 0.5565 - slantness_loss: 0.9138 - tilt_loss: 0.5150 - entry_stroke_a_loss: 0.1503 - staff_of_a_loss: 1.0983 - formation_n_loss: 0.5101 - staff_of_d_loss: 0.8470 - exit_stroke_d_loss: 1.1728 - word_formation_loss: 0.6700 - constancy_loss: 0.6644 - pen_pressure_categorical_accuracy: 0.8067 - letter_spacing_categorical_accuracy: 0.5243 - size_categorical_accuracy: 0.6592 - dimension_categorical_accuracy: 0.6376 - is_lowercase_categorical_accuracy: 0.9848 - is_continuous_categorical_accuracy: 0.7338 - slantness_categorical_accuracy: 0.6032 - tilt_categorical_accuracy: 0.8012 - entry_stroke_a_categorical_accuracy: 0.9525 - staff_of_a_categorical_accuracy: 0.5810 - formation_n_categorical_accuracy: 0.7626 - staff_of_d_categorical_accuracy: 0.6170 - exit_stroke_d_categorical_accuracy: 0.4808 - word_formation_categorical_accuracy: 0.6182 - constancy_categorical_accuracy: 0.6157 - val_loss: 10.7246 - val_pen_pressure_loss: 0.4362 - val_letter_spacing_loss: 1.1069 - val_size_loss: 0.7410 - val_dimension_loss: 0.7654 - val_is_lowercase_loss: 0.3201 - val_is_continuous_loss: 0.5196 - val_slantness_loss: 0.9353 - val_tilt_loss: 0.5162 - val_entry_stroke_a_loss: 0.5582 - val_staff_of_a_loss: 1.0940 - val_formation_n_loss: 0.4791 - val_staff_of_d_loss: 0.8475 - val_exit_stroke_d_loss: 1.0847 - val_word_formation_loss: 0.6607 - val_constancy_loss: 0.6597 - val_pen_pressure_categorical_accuracy: 0.7990 - val_letter_spacing_categorical_accuracy: 0.4437 - val_size_categorical_accuracy: 0.6405 - val_dimension_categorical_accuracy: 0.6500 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.7487 - val_slantness_categorical_accuracy: 0.6119 - val_tilt_categorical_accuracy: 0.7895 - val_entry_stroke_a_categorical_accuracy: 0.7522 - val_staff_of_a_categorical_accuracy: 0.5912 - val_formation_n_categorical_accuracy: 0.7837 - val_staff_of_d_categorical_accuracy: 0.6023 - val_exit_stroke_d_categorical_accuracy: 0.5293 - val_word_formation_categorical_accuracy: 0.6190 - val_constancy_categorical_accuracy: 0.6089
# Epoch 9/10
# 1386/1386 [==============================] - 118s 85ms/step - loss: 10.2284 - pen_pressure_loss: 0.4270 - letter_spacing_loss: 0.9782 - size_loss: 0.7426 - dimension_loss: 0.7750 - is_lowercase_loss: 0.2168 - is_continuous_loss: 0.5635 - slantness_loss: 0.9099 - tilt_loss: 0.5069 - entry_stroke_a_loss: 0.1495 - staff_of_a_loss: 1.1161 - formation_n_loss: 0.5037 - staff_of_d_loss: 0.8501 - exit_stroke_d_loss: 1.1571 - word_formation_loss: 0.6756 - constancy_loss: 0.6565 - pen_pressure_categorical_accuracy: 0.8111 - letter_spacing_categorical_accuracy: 0.5242 - size_categorical_accuracy: 0.6560 - dimension_categorical_accuracy: 0.6351 - is_lowercase_categorical_accuracy: 0.9866 - is_continuous_categorical_accuracy: 0.7347 - slantness_categorical_accuracy: 0.6024 - tilt_categorical_accuracy: 0.8061 - entry_stroke_a_categorical_accuracy: 0.9526 - staff_of_a_categorical_accuracy: 0.5705 - formation_n_categorical_accuracy: 0.7649 - staff_of_d_categorical_accuracy: 0.6200 - exit_stroke_d_categorical_accuracy: 0.4903 - word_formation_categorical_accuracy: 0.6072 - constancy_categorical_accuracy: 0.6245 - val_loss: 11.4555 - val_pen_pressure_loss: 0.5353 - val_letter_spacing_loss: 0.9480 - val_size_loss: 0.7313 - val_dimension_loss: 0.8047 - val_is_lowercase_loss: 0.3201 - val_is_continuous_loss: 0.6755 - val_slantness_loss: 0.9133 - val_tilt_loss: 0.5515 - val_entry_stroke_a_loss: 0.2016 - val_staff_of_a_loss: 1.4177 - val_formation_n_loss: 0.4873 - val_staff_of_d_loss: 1.0482 - val_exit_stroke_d_loss: 1.3370 - val_word_formation_loss: 0.8168 - val_constancy_loss: 0.6674 - val_pen_pressure_categorical_accuracy: 0.7403 - val_letter_spacing_categorical_accuracy: 0.5396 - val_size_categorical_accuracy: 0.6616 - val_dimension_categorical_accuracy: 0.6259 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.5952 - val_slantness_categorical_accuracy: 0.6018 - val_tilt_categorical_accuracy: 0.7538 - val_entry_stroke_a_categorical_accuracy: 0.9370 - val_staff_of_a_categorical_accuracy: 0.3341 - val_formation_n_categorical_accuracy: 0.7773 - val_staff_of_d_categorical_accuracy: 0.5825 - val_exit_stroke_d_categorical_accuracy: 0.3895 - val_word_formation_categorical_accuracy: 0.5208 - val_constancy_categorical_accuracy: 0.5986
# Epoch 10/10
# 1386/1386 [==============================] - 118s 85ms/step - loss: 10.5084 - pen_pressure_loss: 0.4267 - letter_spacing_loss: 0.9763 - size_loss: 0.7483 - dimension_loss: 0.7720 - is_lowercase_loss: 0.2340 - is_continuous_loss: 0.5481 - slantness_loss: 0.9162 - tilt_loss: 0.5100 - entry_stroke_a_loss: 0.4135 - staff_of_a_loss: 1.1108 - formation_n_loss: 0.5138 - staff_of_d_loss: 0.8396 - exit_stroke_d_loss: 1.1778 - word_formation_loss: 0.6645 - constancy_loss: 0.6569 - pen_pressure_categorical_accuracy: 0.8102 - letter_spacing_categorical_accuracy: 0.5260 - size_categorical_accuracy: 0.6534 - dimension_categorical_accuracy: 0.6352 - is_lowercase_categorical_accuracy: 0.9855 - is_continuous_categorical_accuracy: 0.7393 - slantness_categorical_accuracy: 0.6027 - tilt_categorical_accuracy: 0.8036 - entry_stroke_a_categorical_accuracy: 0.9481 - staff_of_a_categorical_accuracy: 0.5758 - formation_n_categorical_accuracy: 0.7583 - staff_of_d_categorical_accuracy: 0.6225 - exit_stroke_d_categorical_accuracy: 0.4806 - word_formation_categorical_accuracy: 0.6215 - constancy_categorical_accuracy: 0.6257 - val_loss: 12.8286 - val_pen_pressure_loss: 0.4808 - val_letter_spacing_loss: 1.1683 - val_size_loss: 0.7562 - val_dimension_loss: 1.0221 - val_is_lowercase_loss: 0.3201 - val_is_continuous_loss: 0.5656 - val_slantness_loss: 1.2855 - val_tilt_loss: 0.6130 - val_entry_stroke_a_loss: 1.0242 - val_staff_of_a_loss: 1.2171 - val_formation_n_loss: 0.5235 - val_staff_of_d_loss: 1.3158 - val_exit_stroke_d_loss: 1.1269 - val_word_formation_loss: 0.7479 - val_constancy_loss: 0.6615 - val_pen_pressure_categorical_accuracy: 0.8136 - val_letter_spacing_categorical_accuracy: 0.3985 - val_size_categorical_accuracy: 0.6206 - val_dimension_categorical_accuracy: 0.5253 - val_is_lowercase_categorical_accuracy: 0.9801 - val_is_continuous_categorical_accuracy: 0.7117 - val_slantness_categorical_accuracy: 0.4625 - val_tilt_categorical_accuracy: 0.7895 - val_entry_stroke_a_categorical_accuracy: 0.9365 - val_staff_of_a_categorical_accuracy: 0.4538 - val_formation_n_categorical_accuracy: 0.7350 - val_staff_of_d_categorical_accuracy: 0.4459 - val_exit_stroke_d_categorical_accuracy: 0.5152 - val_word_formation_categorical_accuracy: 0.5970 - val_constancy_categorical_accuracy: 0.6174

# %%
xai_NN.evaluate_generator(valGenObj,steps=1)
# Out:
# [9.321702003479004,
#  0.3236043453216553,
#  0.9752821922302246,
#  0.7220070958137512,
#  0.7293941378593445,
#  0.05708406865596771,
#  0.44710293412208557,
#  0.7853134274482727,
#  0.489477276802063,
#  0.1898888498544693,
#  1.039496898651123,
#  0.5069620609283447,
#  0.7590380311012268,
#  1.0361294746398926,
#  0.6277732253074646,
#  0.6331472992897034,
#  0.8657664656639099,
#  0.5353454947471619,
#  0.6814932227134705,
#  0.669579029083252,
#  0.9793487191200256,
#  0.803812563419342,
#  0.6608419418334961,
#  0.7950754761695862,
#  0.9459888935089111,
#  0.6036536693572998,
#  0.7474185824394226,
#  0.6378077864646912,
#  0.5655282139778137,
#  0.6417791843414307,
#  0.6378077864646912]

# %%
output = xai_NN.predict_generator(testGenObj,steps=1)
