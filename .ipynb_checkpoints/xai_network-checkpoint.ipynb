# %%
import numpy as np
import pandas as pd
import cv2
from matplotlib import pyplot as plt
from keras.regularizers import l1_l2
from keras.models import Model, clone_model
from keras.layers import Input, Flatten, Dense, Dropout, Lambda, Conv2D, MaxPooling2D, Flatten, BatchNormalization, concatenate, Activation, Subtract, merge, Reshape, UpSampling2D
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from keras import backend as K
from keras import optimizers
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm_notebook
from os import listdir
from os.path import isfile, join
from keras.utils import to_categorical
# %matplotlib inline

# %%
stickyPath = "../dataset/seen-dataset/TrainingSet/"
seenData = [f for f in listdir(stickyPath) if isfile(join(stickyPath, f))]
testData = [f for f in listdir("../dataset/seen-dataset/ValidationSet/") if isfile(join("../dataset/seen-dataset/ValidationSet/", f))]

# %%
trainData = seenData[0:int(len(seenData)*0.9)]
valData = seenData[int(len(seenData)*0.9):]

# %%
feature_data = pd.read_csv("../dataset/15features.csv")

# %%
feature_data.head()
# Out:
#         imagename  pen_pressure  letter_spacing  size  dimension  \
# 0  0968c_num1.png             2               2     2          1
# 1  0809c_num2.png             2               2     2          2
# 2  0237b_num6.png             2               2     2          2
# 3  0069b_num2.png             2               2     2          1
# 4  0966c_num4.png             2               2     2          2
#
#    is_lowercase  is_continuous  slantness  tilt  entry_stroke_a  staff_of_a  \
# 0             2              2          3     2               1           2
# 1             2              2          3     1               1           2
# 2             2              2          2     2               1           2
# 3             2              2          1     1               1           1
# 4             2              2          2     1               1           2
#
#    formation_n  staff_of_d  exit_stroke_d  word_formation  constancy
# 0            2           3              2               2          1
# 1            2           3              1               2          2
# 2            2           2              2               2          2
# 3            1           1              1               1          1
# 4            2           2              2               2          2

# %%
cat_dict = {}
for idx,columns in enumerate(feature_data.columns):
    if columns != "imagename":
        cat_dict[idx]=len(np.unique(feature_data[columns]))
cat_dict
# Out:
# {1: 2,
#  2: 3,
#  3: 3,
#  4: 3,
#  5: 2,
#  6: 2,
#  7: 4,
#  8: 2,
#  9: 2,
#  10: 4,
#  11: 2,
#  12: 3,
#  13: 4,
#  14: 2,
#  15: 2}

# %%
for idx,columns in enumerate(feature_data.columns):
    if columns != "imagename":
        feature_data[str(columns)] = feature_data[str(columns)] - 1
        feature_data[str(columns)] = list(to_categorical(feature_data[str(columns)],num_classes=cat_dict[idx]))

# %%
train_features = feature_data[feature_data["imagename"].isin(trainData)]
val_features = feature_data[feature_data["imagename"].isin(valData)]
test_features = feature_data[feature_data["imagename"].isin(testData)]

# %%
def datagen(batchSize,train_features,stickyPath):
    idx = 0
    while(True):
        subset = train_features.sample(n=batchSize).reset_index(drop=True)
        data = list(subset.imagename)
        returnInput=[]
        returnOutput=[]
        f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15 = [],[],[],[],[],[],[],[],[],[],[],[],[],[],[]
        for image in data:
            skeleton = []
            left = cv2.imread(str(stickyPath+image),cv2.IMREAD_GRAYSCALE)
            #right = data.iloc[row,1]
            #right = cv2.imread(str("../dataset/seen-dataset/TrainingSet/"+right),cv2.IMREAD_GRAYSCALE)
            
            # Floating Point
            leftImage = left.astype('float32')
            leftImage /= 255
            leftImage = 1 - leftImage
            #rightImage = right.astype('float32')
            #rightImage /= 255
            
            temp=[leftImage]
            
            skeleton.append(temp)
            
            returnInput.append(skeleton) 
            features = train_features[train_features.imagename == image].iloc[:,1:].values
            f1.append(np.array(features[0][0],dtype='int32').tolist())
            f2.append(np.array(features[0][1],dtype='int32').tolist())
            f3.append(np.array(features[0][2],dtype='int32').tolist())
            f4.append(np.array(features[0][3],dtype='int32').tolist())
            f5.append(np.array(features[0][4],dtype='int32').tolist())
            f6.append(np.array(features[0][5],dtype='int32').tolist())
            f7.append(np.array(features[0][6],dtype='int32').tolist())
            f8.append(np.array(features[0][7],dtype='int32').tolist())
            f9.append(np.array(features[0][8],dtype='int32').tolist())
            f10.append(np.array(features[0][9],dtype='int32').tolist())
            f11.append(np.array(features[0][10],dtype='int32').tolist())
            f12.append(np.array(features[0][11],dtype='int32').tolist())
            f13.append(np.array(features[0][12],dtype='int32').tolist())
            f14.append(np.array(features[0][13],dtype='int32').tolist())
            f15.append(np.array(features[0][14],dtype='int32').tolist())
            
        returnInput = np.array(returnInput)
        returnInput = returnInput.reshape(batchSize,64,64)
        
        blank =[]
        
        blank.append(returnInput)
        
        returnInput = np.array(blank)
        
        returnInput = np.moveaxis(returnInput,0,3)
        
        outList = [f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15]

        for idx,item in enumerate(outList):
            outList[idx] = np.array(item)
        
        yield returnInput,outList

# %%
trainGenObj = datagen(10,train_features,stickyPath)

# %%
image,feat= next(trainGenObj)

# %%
feat[0].shape
# Out:
# (10, 2)

# %%
input_img = Input(shape=(64, 64, 1))  # adapt this if using `channels_first` image data format
x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)
encoded = Flatten()(x)
encoded = Dense(8*8*8, activation='relu', name='latent')(encoded)
# model = Model(input_img,encoded)
# print(model.summary())
# at this point the representation is (4, 4, 8) i.e. 128-dimensional
r = Reshape(target_shape=(8,8,8))(encoded)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(r)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
#x = BatchNormalization()(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same',name='output')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='RMSprop', loss='binary_crossentropy')

#display(SVG(model_to_dot(autoencoder, show_layer_names=True, show_shapes=True, rankdir='TB').create(prog='dot', format='svg')))
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/aml/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
autoencoder.load_weights("weights/simple_ae_maxpool_Seen_weights_v1.h5")

# %%
encoder = Model(inputs=autoencoder.inputs,outputs=autoencoder.get_layer('latent').output)

# %%
#display(SVG(model_to_dot(encoder, show_layer_names=True, show_shapes=True, rankdir='TB').create(prog='dot', format='svg')))

# %% [markdown]
# ### Frezzing weights

# %%
for layer in encoder.layers:
    layer.trainable = False

# %%
def baseModel(_input,outputCat,name):
    layer1 = Dense(512,activation='relu',kernel_initializer="glorot_normal")(_input)
    layer1 = BatchNormalization()(layer1)
    layer4 = Dense(outputCat,activation='softmax',name=str(name),kernel_initializer="glorot_normal")(layer1)
    return layer4

# %%
cat_dict[1]
# Out:
# 2

# %%
featureModelList = []
feat
for idx,column in enumerate(train_features.columns):
    if(idx != 0):
        featureModelList.append(baseModel(encoder.output,cat_dict[idx],column))
featureModelList
# Out:
# [<tf.Tensor 'pen_pressure_1/Softmax:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'letter_spacing_1/Softmax:0' shape=(?, 3) dtype=float32>,
#  <tf.Tensor 'size_1/Softmax:0' shape=(?, 3) dtype=float32>,
#  <tf.Tensor 'dimension_1/Softmax:0' shape=(?, 3) dtype=float32>,
#  <tf.Tensor 'is_lowercase_1/Softmax:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'is_continuous_1/Softmax:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'slantness_1/Softmax:0' shape=(?, 4) dtype=float32>,
#  <tf.Tensor 'tilt_1/Softmax:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'entry_stroke_a_1/Softmax:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'staff_of_a_1/Softmax:0' shape=(?, 4) dtype=float32>,
#  <tf.Tensor 'formation_n_1/Softmax:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'staff_of_d_1/Softmax:0' shape=(?, 3) dtype=float32>,
#  <tf.Tensor 'exit_stroke_d_1/Softmax:0' shape=(?, 4) dtype=float32>,
#  <tf.Tensor 'word_formation_1/Softmax:0' shape=(?, 2) dtype=float32>,
#  <tf.Tensor 'constancy_1/Softmax:0' shape=(?, 2) dtype=float32>]

# %%
xai_NN = Model(encoder.input,featureModelList)

# %%
display(SVG(model_to_dot(xai_NN, show_layer_names=True, show_shapes=True, rankdir='TB').create(prog='dot', format='svg')))

# %%
lossesDict = {}
for idx,column in enumerate(train_features.columns):
    if idx  != 0:
        lossesDict[columns] = "categorical_crossentropy"

adam = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
xai_NN.compile(optimizer=adam, loss='categorical_crossentropy',metrics=['categorical_accuracy'])

# %%
batchSize=10
trainGenObj = datagen(batchSize,train_features,stickyPath)
valGenObj = datagen(len(val_features),val_features,stickyPath)
testGenObj = datagen(len(test_features),test_features,"../dataset/seen-dataset/ValidationSet/")

# %%
LOG_DIR = './log/xai/seen'
#runIter = 0

# %%
mc = ModelCheckpoint(filepath='weights/xai_seen_weights_v1.h5', 
                     monitor='val_loss',period=1,save_best_only=True,
                     save_weights_only=True,mode='auto',verbose=1)
es = EarlyStopping(patience=700, monitor='val_loss', min_delta=0.0005, mode='auto')
tbCallBack = TensorBoard(log_dir=str(LOG_DIR+"/run"+str(runIter)), histogram_freq=0,
                         write_graph=True,
                         write_grads=True,
                         batch_size=batchSize,
                         write_images=True)
runIter+=1

# %%
xai_NN.fit_generator(
    trainGenObj,
    epochs=1000,
    verbose=1,
    validation_data=valGenObj,
    validation_steps=1,
    steps_per_epoch=20,
    callbacks=[es,tbCallBack]
)
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 9s 470ms/step - loss: 19.1976 - pen_pressure_loss: 0.7058 - letter_spacing_loss: 1.7368 - size_loss: 1.3356 - dimension_loss: 1.5757 - is_lowercase_loss: 0.4404 - is_continuous_loss: 1.2181 - slantness_loss: 1.8803 - tilt_loss: 0.8716 - entry_stroke_a_loss: 0.5854 - staff_of_a_loss: 1.9922 - formation_n_loss: 1.0273 - staff_of_d_loss: 1.7864 - exit_stroke_d_loss: 1.7572 - word_formation_loss: 1.1030 - constancy_loss: 1.1820 - pen_pressure_categorical_accuracy: 0.7300 - letter_spacing_categorical_accuracy: 0.4400 - size_categorical_accuracy: 0.6000 - dimension_categorical_accuracy: 0.4800 - is_lowercase_categorical_accuracy: 0.8500 - is_continuous_categorical_accuracy: 0.6400 - slantness_categorical_accuracy: 0.4250 - tilt_categorical_accuracy: 0.7300 - entry_stroke_a_categorical_accuracy: 0.8000 - staff_of_a_categorical_accuracy: 0.4150 - formation_n_categorical_accuracy: 0.7000 - staff_of_d_categorical_accuracy: 0.4250 - exit_stroke_d_categorical_accuracy: 0.4450 - word_formation_categorical_accuracy: 0.5650 - constancy_categorical_accuracy: 0.5900 - val_loss: 84.1995 - val_pen_pressure_loss: 6.8053 - val_letter_spacing_loss: 4.1328 - val_size_loss: 5.4940 - val_dimension_loss: 7.8451 - val_is_lowercase_loss: 0.2266 - val_is_continuous_loss: 1.2704 - val_slantness_loss: 4.0302 - val_tilt_loss: 5.2434 - val_entry_stroke_a_loss: 14.7370 - val_staff_of_a_loss: 6.3665 - val_formation_n_loss: 2.9595 - val_staff_of_d_loss: 10.0518 - val_exit_stroke_d_loss: 8.8379 - val_word_formation_loss: 1.7842 - val_constancy_loss: 4.4151 - val_pen_pressure_categorical_accuracy: 0.4091 - val_letter_spacing_categorical_accuracy: 0.5147 - val_size_categorical_accuracy: 0.5187 - val_dimension_categorical_accuracy: 0.5131 - val_is_lowercase_categorical_accuracy: 0.9658 - val_is_continuous_categorical_accuracy: 0.5616 - val_slantness_categorical_accuracy: 0.3288 - val_tilt_categorical_accuracy: 0.2129 - val_entry_stroke_a_categorical_accuracy: 0.0699 - val_staff_of_a_categorical_accuracy: 0.0675 - val_formation_n_categorical_accuracy: 0.7736 - val_staff_of_d_categorical_accuracy: 0.1025 - val_exit_stroke_d_categorical_accuracy: 0.4369 - val_word_formation_categorical_accuracy: 0.4241 - val_constancy_categorical_accuracy: 0.5806
# Epoch 2/1000
# Epoch 302/1000
# 11/20 [===============>..............] - ETA: 0s - loss: 8.7480 - pen_pressure_loss: 0.2944 - letter_spacing_loss: 0.9920 - size_loss: 0.5398 - dimension_loss: 0.6434 - is_lowercase_loss: 0.0223 - is_continuous_loss: 0.5280 - slantness_loss: 0.8480 - tilt_loss: 0.3615 - entry_stroke_a_loss: 0.2089 - staff_of_a_loss: 1.1406 - formation_n_loss: 0.5111 - staff_of_d_loss: 0.5248 - exit_stroke_d_loss: 0.9482 - word_formation_loss: 0.6032 - constancy_loss: 0.5817 - pen_pressure_categorical_accuracy: 0.8545 - letter_spacing_categorical_accuracy: 0.5364 - size_categorical_accuracy: 0.7727 - dimension_categorical_accuracy: 0.6636 - is_lowercase_categorical_accuracy: 0.9818 - is_continuous_categorical_accuracy: 0.7364 - slantness_categorical_accuracy: 0.6545 - tilt_categorical_accuracy: 0.8545 - entry_stroke_a_categorical_accuracy: 0.9364 - staff_of_a_categorical_accuracy: 0.5091 - formation_n_categorical_accuracy: 0.7000 - staff_of_d_categorical_accuracy: 0.7636 - exit_stroke_d_categorical_accuracy: 0.5909 - word_formation_categorical_accuracy: 0.6727 - constancy_categorical_accuracy: 0.7182
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-b20ee3134f42> in <module>
#       6     validation_steps=1,
#       7     steps_per_epoch=20,
# ----> 8     callbacks=[es,tbCallBack]
#       9 )
#
# ~/anaconda3/envs/aml/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/aml/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/envs/aml/lib/python3.7/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~/anaconda3/envs/aml/lib/python3.7/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/anaconda3/envs/aml/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/aml/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/aml/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
xai_NN.evaluate_generator(valGenObj,steps=1)
# Out:
# [9.321702003479004,
#  0.3236043453216553,
#  0.9752821922302246,
#  0.7220070958137512,
#  0.7293941378593445,
#  0.05708406865596771,
#  0.44710293412208557,
#  0.7853134274482727,
#  0.489477276802063,
#  0.1898888498544693,
#  1.039496898651123,
#  0.5069620609283447,
#  0.7590380311012268,
#  1.0361294746398926,
#  0.6277732253074646,
#  0.6331472992897034,
#  0.8657664656639099,
#  0.5353454947471619,
#  0.6814932227134705,
#  0.669579029083252,
#  0.9793487191200256,
#  0.803812563419342,
#  0.6608419418334961,
#  0.7950754761695862,
#  0.9459888935089111,
#  0.6036536693572998,
#  0.7474185824394226,
#  0.6378077864646912,
#  0.5655282139778137,
#  0.6417791843414307,
#  0.6378077864646912]

# %%
output = xai_NN.predict_generator(testGenObj,steps=1)
