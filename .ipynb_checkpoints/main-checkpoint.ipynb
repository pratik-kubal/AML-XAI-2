# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../dataset/AND_dataset/AND_dataset/AND_features.csv")
data = data.iloc[:,1:]

# %%
data["ImageId"] = data.ImageId.str.split("[a-z]",expand=True)

# %%
tempData = data.iloc[:,1:]

# %%
from pgmpy.estimators import HillClimbSearch, K2Score
import networkx as nx
import pylab as plt

# %%
data1 = data.sample(frac=1)
data1 = data1.add_prefix('w1_')
data2 = data.sample(frac=1)
data2 = data2.add_prefix('w2_')

# %%
negSamples = pd.concat([data1.reset_index(drop=True),data2.reset_index(drop=True)],axis=1)

# %%
writers = np.unique(data.ImageId)

# %%
skeleton = pd.DataFrame()
for writer in writers:
    query = str("ImageId == '"+str(writer)+"'")
    test = data.query(str(query))
    data1 = test.sample(frac=1)
    data1 = data1.add_prefix('w1_')
    data2 = test.sample(frac=1)
    data2 = data2.add_prefix('w2_')
    test = pd.concat([data1.reset_index(drop=True),data2.reset_index(drop=True)],axis=1)
    skeleton = skeleton.append(test)

# %%
bigBadDataset = negSamples.append(skeleton).reset_index(drop=True)

# %%
bigBadDataset["sameWriter"]=0

# %%
bigBadDataset.sameWriter  = np.where(bigBadDataset["w1_ImageId"] == bigBadDataset["w2_ImageId"],1,0)

# %%
bigBadDataset = bigBadDataset.drop(["w1_ImageId","w2_ImageId"],axis=1)

# %%
bigBadDataset.w1_f9 = bigBadDataset.w1_f9 - 1

# %%
bigBadDataset.w2_f9 = bigBadDataset.w2_f9 - 1

# %%
np.unique(bigBadDataset.w1_f9)
# Out:
# array([0, 1])

# %%
est = HillClimbSearch(bigBadDataset, scoring_method=K2Score(bigBadDataset))
ssj4Model = est.estimate(max_indegree=4)

# %%
nx.draw(ssj4Model, with_labels=True)
plt.show()

# %%
mle = MaximumLikelihoodEstimator(ssj4Model, bigBadDataset)
for var in bigBadDataset.columns:
    ssj4Model.add_cpds(mle.estimate_cpd(var))

# %%
from pgmpy.readwrite import BIFWriter

# %%
model_data = BIFWriter(ssj4Model)
model_data.write_bif(filename='ssj4Model.bif')

# %%
bigBadDataset
# Out:
#       w1_f1  w1_f2  w1_f3  w1_f4  w1_f5  w1_f6  w1_f7  w1_f8  w1_f9  w2_f1  \
# 0         2      0      1      0      1      1      0      2      1      0
# 1         0      1      1      2      2      2      1      0      1      3
# 2         3      0      2      3      0      2      0      3      1      0
# 3         0      1      1      2      2      2      1      2      1      2
# 4         1      1      1      0      2      1      0      0      1      2
# 5         2      2      1      1      2      2      1      4      1      1
# 6         3      1      1      1      2      0      0      4      1      3
# 7         2      2      1      0      0      2      0      3      1      1
# 8         3      1      1      0      1      2      0      1      1      1
# 9         0      1      1      0      0      2      0      2      1      3
# 10        2      0      1      0      2      2      1      2      1      1
# 11        3      0      1      0      2      2      3      2      1      0
# 12        1      0      0      2      2      3      1      3      1      1
# 13        2      1      0      2      2      1      1      1      1      2
# 14        0      1      1      3      2      2      1      1      0      3
# 15        2      1      1      3      2      3      3      4      1      3
# 16        3      4      1      0      2      2      0      4      1      0
# 17        0      1      0      2      2      3      3      4      1      1
# 18        3      1      2      4      2      2      3      2      1      1
# 21        1      1      0      0      2      2      2      0           0
# 22        0      0      0      2      2      0      2      1           0
# 23        4      2      4      2      2      0      3      1           0
# 24        1      1      0      2      0      1      2      1           0
# 25        4      0      3      2      3      1      3      1           0
# 26        2      1      0      2      2      0      1      1           0
# 27        2      1      3      2      2      0      0      1           0
# 28        1      0      0      2      2      3      2      1           0
# 29        4      1      4      2      2      2      1      0           0
# ...     ...    ...    ...    ...    ...    ...    ...    ...         ...
# 2022      4      1      0      2      2      3      4      1           1
# 2023      1      1      3      2      3      0      1      1           1
# 2024      1      1      0      0      2      0      1      1           1
# 2025      1      1      0      2      2      1      2      1           1
# 2026      1      1      0      0      3      0      3      1           1
# 2027      1      0      3      2      1      1      2      0           1
# 2028      0      1      0      2      1      1      3      1           1
# 2029      0      1      3      2      3      0      0      1           1
# 2030      0      1      1      2      1      0      2      1           1
# 2031      4      1      1      2      1      0      2      1           1
# 2032      2      1      3      2      2      1      4      1           1
# 2033      1      1      0      2      1      1      1      0           1
# 2034      1      1      0      2      2      3      3      1           1
# 2035      4      1      3      2      2      3      2      1           1
# 2036      1      1      1      2      1      1      3      1           1
# 2037      1      1      3      2      1      1      1      0           1
# 2038      0      1      1      2      2      1      1      1           1
# 2039      0      1      3      2      2      1      1      1           1
# 2040      1      1      1      2      2      1      1      0           1
# 2041      1      1      2      2      1      0      1      1           1
# 2042      2      1      1      2      3      0      3      1           1
# 2043      1      2      3      3      2      0      1      1           1
# 2044      0      1      0      2      2      2      1      0           1
# 2045      2      1      0      0      2      0      2      1           1
# 2046      1      1      3      2      3      0      0      1           1
# 2047      1      1      0      2      2      2      2      1           1
# 2048      4      1      3      2      2      0      1      1           1
# 2049      1      1      3      0      2      0      2      1           1
# 2050      1      0      2      2      2      0      0      1           1
# 2051      4      1      4      2      2      0      2      1           1
#
# [2052 rows x 19 columns]

# %%
from pgmpy.inference import VariableElimination

# %%
inference = VariableElimination(ssj4Model)

# %%
3 	1 	0 	2 	2 	2 	0 	0 	1 	2 	4 	1 	4 	2 	2 	0 	2 	1

# %%
test = inference.query(variables=['sameWriter'],evidence={'w1_f1':3, 'w1_f2':1, 'w1_f3':0, 'w1_f4':2, 'w1_f5':2, 'w1_f6':2, 'w1_f7':0, 'w1_f8':0, 'w1_f9':1, 'w2_f1':2, 'w2_f2':4, 'w2_f3':1, 'w2_f4':4,'w2_f5':2,'w2_f6':2,'w2_f7':0,'w2_f8':2,'w2_f9':1})

# %%
print(test['sameWriter'])
# Out:
# +--------------+-------------------+
# | sameWriter   |   phi(sameWriter) |
# +==============+===================+
# | sameWriter_0 |            0.8422 |
# +--------------+-------------------+
# | sameWriter_1 |            0.1578 |
# +--------------+-------------------+

# %%
acc = 0
for rows in range(len(bigBadDataset)):
    inf = inference.query(variables=['sameWriter'],evidence=
               dict(zip(bigBadDataset.columns[:18],list(bigBadDataset.iloc[rows,:18]))))
    if np.argmax(inf['sameWriter'].values) == int(bigBadDataset.iloc[rows,18:]):
        acc +=1

# %%
acc/len(bigBadDataset)
# Out:
# 0.7222222222222222
